# %% [markdown]
# # Анализ и прогнозирование временных рядов методами искусственного интеллекта
#
# ## **Практическая работа 6. Поиск эволюционирующих шаблонов с помощью матричного профиля ряда.**

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir(r'/content/drive/MyDrive/TimeSeriesCourse/practice/06 Chains')

# %% [markdown]
# ## **Часть 1.** Поиск цепочек временного ряда.

# %% [markdown]
# Импорт библиотек и модулей

# %%
# !pip install stumpy
# Out:
# Collecting stumpy
#   Downloading stumpy-1.12.0-py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.1/169.1 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from stumpy) (1.23.5)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from stumpy) (1.11.3)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.10/dist-packages (from stumpy) (0.58.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.2->stumpy) (0.41.1)
# Installing collected packages: stumpy
# Successfully installed stumpy-1.12.0

# %%
import stumpy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import stumpy
from sklearn.metrics import mean_squared_error

# %% [markdown]
# В первом задании вам предстоит выполнить поиск эволюционирующих шаблонов временного ряда. Выполните считывание набора данных [Rotation Matrix](datasets/Rotation%20Matrix.txt), найдите в нем самую длинную цепочку и выведите индексы начала звеньев этой цепочки.

# %%
fig, ax = plt.subplots(figsize=(16, 2))
ts = np.loadtxt('datasets/Rotation Matrix.txt')
ax.plot(ts)

# %%
# INSERT YOUR CODE
m = 30
mp = stumpy.stump(ts, m=m)
all_chain_set, unanchored_chain = stumpy.allc(mp[:, 2], mp[:, 3])

# %%
unanchored_chain
# Out:
# array([144, 376, 410, 644, 841])

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов.

# %% [markdown]
# С помощью функции alloc на основе матричного профиля был выполнен поиск цепочек. На педставленом наборе самая длинная цепочка состоит из 5 звеньев с индексами 144, 376, 410, 644, 841.

# %% [markdown]
# ## **Часть 2. Визуализация цепочек**

# %% [markdown]
# Выполните визуализацию найденных в прошлом задании цепочек: постройте график временного ряда, на котором выделены звенья цепочек. Также постройте график, на котором изображены только сами звенья.

# %%
import itertools

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# %%
unanchored_chain
# Out:
# array([144, 376, 410, 644, 841])

# %%
# INSERT YOUR CODE
fig, ax = plt.subplots(figsize=(16, 2))
plt.plot(ts, linewidth=1, color='black')
for i in range(unanchored_chain.shape[0]):
    y = ts[unanchored_chain[i]:unanchored_chain[i]+m]
    x = range(unanchored_chain[i], unanchored_chain[i]+m)
    plt.plot(x, y, linewidth=2)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 2))
for i in range(unanchored_chain.shape[0]):
    y = ts[unanchored_chain[i]:unanchored_chain[i]+m]
    x = range(unanchored_chain[i], unanchored_chain[i]+m)
    plt.plot(x, y)
plt.show()

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов.

# %% [markdown]
# При визуализации звеньев, найденных в первой части, можно заметить, что звенья визуально схожи.

# %% [markdown]
# ## **Часть 3.** Предсказывание значений ряда на основе цепочек.

# %% [markdown]
# Предскажите значения последнего звена цепочки, вычислив разность между двумя предыдущими звеньями цепочки. Сравните полученное предсказание с истинным значением.

# %%
# INSERT YOUR CODE

# %% [markdown]
# ❓ Проанализируйте и изложите содержательный смысл полученных результатов.
